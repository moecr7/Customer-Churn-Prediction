# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("churndata.csv")

print(df['Churn'].value_counts(normalize=True))

df.head()
# Out:
# Churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Count plot of the target column 'Churn'
sns.countplot(x='Churn', data=df)

# Set plot title
plt.title('Target Distribution')

# Show the plot
plt.show()
# Out:
# Text(0.5, 1.0, 'Target Distribution')

# %%
# Select only numeric columns
numerics = df.select_dtypes(include='number').columns

# Plot histograms for all numeric features
df[numerics].hist(figsize=(12, 10), bins=30)

# Add a title to the whole figure
plt.suptitle('Distributions of Numerical Features')

# Show the plots
plt.show()
# Out:
# Text(0.5, 0.98, 'Distributions of Numerical Features')

# %%
# Create a boxplot of MonthlyCharges grouped by Churn status
sns.boxplot(x='Churn', y='MonthlyCharges', data=df)

# Show the plot
plt.title('Monthly Charges by Churn')
plt.show()
# Out:
# <Axes: xlabel='Churn', ylabel='MonthlyCharges'>

# %%
# Count plot of Contract types, segmented by Churn status (Yes/No)
sns.countplot(x='Contract', hue='Churn', data=df)

# Add title for better readability
plt.title('Churn Count by Contract Type')
plt.show()
# Out:
# <Axes: xlabel='Contract', ylabel='count'>
